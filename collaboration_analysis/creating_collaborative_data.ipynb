# %%
import sys
import os

folder_path = os.path.dirname(os.path.abspath(__file__)) if '__file__' in globals() else os.getcwd()

sys.path.append(os.path.abspath(os.path.join(folder_path, '..')))

from csv_analysis import *

# %% [markdown]
# ## View full data before filtering

# %%
df = read_first_n_rows("../data/q2/merged_openalex_works_data.csv", nrows=15)
df
# Out:
#                              work_id  publication_year  \
# 0    https://openalex.org/W100000002              1988
# 1    https://openalex.org/W100000002              1988
# 2   https://openalex.org/W1000000251              1990
# 3   https://openalex.org/W1000000251              1990
# 4   https://openalex.org/W1000000589              2010
# 5   https://openalex.org/W1000000589              2010
# 6   https://openalex.org/W1000001125              2001
# 7   https://openalex.org/W1000001192              1988
# 8   https://openalex.org/W1000001192              1988
# 9   https://openalex.org/W1000001555              2011
# 10  https://openalex.org/W1000001555              2011
# 11  https://openalex.org/W1000002278              2015
# 12  https://openalex.org/W1000002278              2015
# 13  https://openalex.org/W1000002278              2015
# 14  https://openalex.org/W1000002278              2015
#
#                       institution_id         country country_code  \
# 0   https://openalex.org/I4210095140   United States           US
# 1   https://openalex.org/I4210095140   United States           US
# 2   https://openalex.org/I1292966370  United Kingdom           GB
# 3   https://openalex.org/I1292966370  United Kingdom           GB
# 4      https://openalex.org/I7877124         Germany           DE
# 5      https://openalex.org/I7877124         Germany           DE
# 6    https://openalex.org/I231086526          Poland           PL
# 7   https://openalex.org/I1328594524   United States           US
# 8   https://openalex.org/I4210128618   United States           US
# 9   https://openalex.org/I2802849423   United States           US
# 10  https://openalex.org/I2802849423   United States           US
# 11   https://openalex.org/I119868032           China           CN
# 12   https://openalex.org/I119868032           China           CN
# 13   https://openalex.org/I119868032           China           CN
# 14   https://openalex.org/I119868032           China           CN
#
#            city  geonames_city_id author_position  \
# 0        Durham           4464368           first
# 1        Durham           4464368            last
# 2        London           2643743           first
# 3        London           2643743            last
# 4        Berlin           2950159           first
# 5        Berlin           2950159            last
# 6       Siedlce            759412           first
# 7   Kansas City           4393217           first
# 8   Kansas City           4273837           first
# 9       Lubbock           5525577           first
# 10      Lubbock           5525577            last
# 11     Mingxing           1793691           first
# 12     Mingxing           1793691          middle
# 13     Mingxing           1793691          middle
# 14     Mingxing           1793691          middle
#
#                            author_id
# 0   https://openalex.org/A5012874907
# 1   https://openalex.org/A5006412880
# 2   https://openalex.org/A5057387418
# 3   https://openalex.org/A5035275962
# 4   https://openalex.org/A5091270897
# 5   https://openalex.org/A5071995676
# 6   https://openalex.org/A5060029945
# 7   https://openalex.org/A5072333347
# 8   https://openalex.org/A5072333347
# 9   https://openalex.org/A5050684082
# 10  https://openalex.org/A5050464501
# 11  https://openalex.org/A5088461704
# 12  https://openalex.org/A5037177977
# 13  https://openalex.org/A5022831628
# 14  https://openalex.org/A5011787061

# %% [markdown]
# ## Creating a consolidated file of work and all states of work

# %% [markdown]
# This script uses Dask to lazily read and parallel-process a large CSV, grouping by `work_id` to extract the first `publication_year` and compile unique country lists.
# It then writes the aggregated DataFrame to multiple CSV partitions in the specified output directory while displaying a progress bar via Dask Diagnostics.

# %%
import os
import dask
import dask.dataframe as dd
from dask.diagnostics import ProgressBar

def aggregate_works(
    input_path="../data/q2/merged_openalex_works_data.csv",
    output_dir="../data/collaboration",
    sep=",",
    country_sep=",",
    blocksize="64MB",
):
    """
    Produce one line per work_id:
    work_id, publication_year, countries (comma-separated, unique, unsorted)
    and save as multiple CSV parts with a progress bar.
    """

    # 1) Lazy read
    dtypes  = {
        "work_id": "string",
        "publication_year": "int32",
        "country": "string",
    }
    usecols = ["work_id", "publication_year", "country"]

    df = dd.read_csv(
        input_path,
        sep=sep,
        usecols=usecols,
        dtype=dtypes,
        blocksize=blocksize,
    )

    # 2) First year per work
    years = df.groupby("work_id")["publication_year"].first()

    # 3) Unique-countries array per work, then join with commas
    unique_countries = (
        df.groupby("work_id")["country"]
          .unique()                                 # → numpy array per group
          .map_partitions(
              lambda s: s.apply(lambda arr: country_sep.join(arr)),
              meta=("countries", "object"),
          )
    )

    # 4) Combine the two Series into one DataFrame
    aggregated = dd.concat([years, unique_countries], axis=1).reset_index()

    # 5) Write several CSV parts (one per partition) with progress bar
    os.makedirs(output_dir, exist_ok=True)
    out_pattern = os.path.join(output_dir, "works_year_countries-*.csv")

    print("🟢 Writing output parts (progress bar below)…")
    with ProgressBar():
        tasks = aggregated.to_csv(out_pattern, index=False)   # returns Delayed list
        dask.compute(tasks)

    print(f"✓ Done!  Files written to {output_dir}")

if __name__ == "__main__":
    aggregate_works()
# Out:
# 🟢 Writing output parts (progress bar below)…
# /home/oranbe/.conda/envs/data_mining_project/lib/python3.11/site-packages/dask_expr/_concat.py:146: UserWarning: Concatenating dataframes with unknown divisions.
# We're assuming that the indices of each dataframes are
#  aligned. This assumption is not generally safe.
#   warnings.warn(
# [################################        ] | 81% Completed | 2hr 50ms

# %%
df = read_first_n_rows("../data/collaboration/works_year_countries.csv", nrows=15)
df
# Out:
#                              work_id  publication_year  \
# 0    https://openalex.org/W143756818              1998
# 1   https://openalex.org/W1437651587              1973
# 2    https://openalex.org/W143770321              2000
# 3   https://openalex.org/W1437735228              2003
# 4    https://openalex.org/W143773981              2002
# 5    https://openalex.org/W143775390              2001
# 6   https://openalex.org/W1437804358              2015
# 7    https://openalex.org/W143781885              2012
# 8   https://openalex.org/W1437876792              2015
# 9    https://openalex.org/W143791697              2009
# 10     https://openalex.org/W1438002              2001
# 11  https://openalex.org/W1438053537              2005
# 12   https://openalex.org/W143808035              2014
# 13  https://openalex.org/W1438129022              2015
# 14   https://openalex.org/W143828736              2001
#
#                              countries
# 0                              Germany
# 1                              Czechia
# 2                                China
# 3                        United States
# 4                              Belgium
# 5                               Israel
# 6                            Australia
# 7                               Canada
# 8                        United States
# 9                               France
# 10                              Norway
# 11   United States,Georgia,Spain,Japan
# 12  United Kingdom,Ivory Coast,Tunisia
# 13                      United Kingdom
# 14                       United States

# %% [markdown]
# ## Creating a file only of works that involve collaboration between several countries

# %%
import pandas as pd
from tqdm import tqdm

def filter_multiple_countries(file_path, output_path):
    # Load the data from the CSV file
    df = pd.read_csv(file_path)
    
    # Add a column to count the number of countries per row
    df['countries_count'] = df['countries'].apply(lambda x: len(x.split(',')))
    
    # Filter rows where there are more than one country
    filtered_df = df[df['countries_count'] > 1]
    
    # Drop the 'countries_count' column
    filtered_df = filtered_df.drop(columns=['countries_count'])
    
    # Save the filtered data to a new CSV file
    filtered_df.to_csv(output_path, index=False)
    
    print(f"File saved to {output_path}")

# Example usage
input_file = "../data/collaboration/works_year_countries.csv"
output_file = "../data/collaboration/works_multiple_countries.csv"

# Show progress using tqdm
tqdm.pandas(desc="Processing rows")
filter_multiple_countries(input_file, output_file)
# Out:
# File saved to ../data/collaboration/works_multiple_countries.csv

# %%
df = read_first_n_rows("../data/collaboration/works_multiple_countries.csv", nrows=15)
df
# Out:
#                              work_id  publication_year  \
# 0   https://openalex.org/W1438053537              2005
# 1    https://openalex.org/W143808035              2014
# 2   https://openalex.org/W1438510599              2015
# 3    https://openalex.org/W143872587              2013
# 4   https://openalex.org/W1438912788              2015
# 5    https://openalex.org/W143981305              1995
# 6    https://openalex.org/W143997697              1981
# 7   https://openalex.org/W2051785559              2015
# 8   https://openalex.org/W2051791908              2013
# 9   https://openalex.org/W2051794810              2009
# 10  https://openalex.org/W2051798195              2000
# 11  https://openalex.org/W2051800428              2013
# 12  https://openalex.org/W2051805074              2014
# 13  https://openalex.org/W2051809008              2007
# 14  https://openalex.org/W2051809870              2009
#
#                               countries
# 0     United States,Georgia,Spain,Japan
# 1    United Kingdom,Ivory Coast,Tunisia
# 2          United Kingdom,Israel,France
# 3             Singapore,China,Hong Kong
# 4            Russia,United States,Italy
# 5                 Germany,United States
# 6                 Taiwan,China,Bulgaria
# 7   United States,Brazil,United Kingdom
# 8                      Singapore,Taiwan
# 9                 United States,Georgia
# 10         United States,United Kingdom
# 11             Australia,United Kingdom
# 12                Poland,United Kingdom
# 13            United States,Netherlands
# 14                 Brazil,United States

# %% [markdown]
# ## Creating a file that contains all the works of collaborations of which Israel is one of the countries

# %%
import pandas as pd
from tqdm import tqdm

def filter_multiple_countries(file_path, output_path):
    # Load the data from the CSV file
    df = pd.read_csv(file_path)
    
    # Enable progress_apply on the DataFrame
    tqdm.pandas(desc="Checking for Israel")
    
    # Add a helper column to mark rows where one of the countries is Israel
    df['has_israel'] = df['countries'].progress_apply(
        lambda x: any(country.strip() == 'Israel' for country in x.split(','))
    )
    
    # Filter only the rows with Israel
    filtered_df = df[df['has_israel']]
    
    # Drop the helper column
    filtered_df = filtered_df.drop(columns=['has_israel'])
    
    # Save the filtered data to a new CSV file
    filtered_df.to_csv(output_path, index=False)
    
    print(f"File saved to {output_path}")

# Example usage
input_file  = "../data/collaboration/works_multiple_countries.csv"
output_file = "../data/collaboration/works_israel.csv"

# Process and filter
filter_multiple_countries(input_file, output_file)
# Out:
# Checking for Israel: 100%|██████████| 13305986/13305986 [00:19<00:00, 690678.57it/s]
# File saved to ../data/collaboration/works_israel.csv

# %%
df = read_first_n_rows("../data/collaboration/works_israel.csv", nrows=15)
df
# Out:
#                              work_id  publication_year  \
# 0   https://openalex.org/W1438510599              2015
# 1   https://openalex.org/W2052031909              2010
# 2   https://openalex.org/W2052156706              2013
# 3   https://openalex.org/W2052285261              2013
# 4   https://openalex.org/W2052550778              1988
# 5   https://openalex.org/W2052555612              2011
# 6   https://openalex.org/W2052556251              1998
# 7   https://openalex.org/W2052586778              2007
# 8   https://openalex.org/W2052619683              1998
# 9   https://openalex.org/W2052783340              1999
# 10  https://openalex.org/W2052887879              1993
# 11  https://openalex.org/W2054143913              2009
# 12  https://openalex.org/W2054512567              2012
# 13  https://openalex.org/W2054842377              2007
# 14  https://openalex.org/W2055037451              2007
#
#                        countries
# 0   United Kingdom,Israel,France
# 1                  Israel,Canada
# 2           United States,Israel
# 3                 Israel,Germany
# 4           United States,Israel
# 5           United States,Israel
# 6           United States,Israel
# 7           Israel,United States
# 8                 Finland,Israel
# 9           Israel,United States
# 10          Israel,United States
# 11          United States,Israel
# 12          United States,Israel
# 13        Australia,Japan,Israel
# 14          Israel,United States
