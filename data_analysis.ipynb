# %%
from get_data import *
from visualization_plot import *

# %%
works_per_year = get_total_works_per_year()
plot_bar_chart(works_per_year, 'year', 'total_works_count_per_year', 'Total Works Per Year')

# %%
works_per_year
# Out:
# [{'year': 2012, 'total_works_count_per_year': 7528418},
#  {'year': 2013, 'total_works_count_per_year': 8043720},
#  {'year': 2014, 'total_works_count_per_year': 8346115},
#  {'year': 2015, 'total_works_count_per_year': 8454238},
#  {'year': 2016, 'total_works_count_per_year': 8744214},
#  {'year': 2017, 'total_works_count_per_year': 8785938},
#  {'year': 2018, 'total_works_count_per_year': 9089064},
#  {'year': 2019, 'total_works_count_per_year': 9370917},
#  {'year': 2020, 'total_works_count_per_year': 10058648},
#  {'year': 2021, 'total_works_count_per_year': 9859828},
#  {'year': 2022, 'total_works_count_per_year': 8804371},
#  {'year': 2023, 'total_works_count_per_year': 6229167}]
